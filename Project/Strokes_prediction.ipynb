# %% [markdown]
# # Stroke Prediction System

# %% [markdown]
# ## 🧠 Stroke — Short Description
#
# **Stroke is a medical emergency that occurs when blood flow to part of the brain is blocked or when a blood vessel in the brain bursts, causing brain cells to die due to lack of oxygen.** It can lead to weakness, speech problems, paralysis, memory loss, or even death if not treated quickly.
#
# ---
#
# ## ✅ Types of Stroke
#
# * **Ischemic Stroke** → caused by blood clot blockage
# * **Hemorrhagic Stroke** → caused by bleeding in the brain
# * **TIA (Mini Stroke)** → temporary blockage warning sign.
#
# ---
#
# ## ⚠️ Common Symptoms
#
# Use **FAST**:
#
# * **F** → Face drooping
# * **A** → Arm weakness
# * **S** → Speech difficulty
# * **T** → Time to call emergency help  ([Mayo Clinic][2])
#
# ---
#
# ## 📌 project definition
#
# **Stroke is a sudden interruption of blood supply to the brain that damages brain cells and can cause disability or death.**

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Download Dataset From KaggleHub

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fedesoriano/stroke-prediction-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/fedesoriano/stroke-prediction-dataset/1.archive...
# 100%|██████████| 67.4k/67.4k [00:00<00:00, 36.3MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fedesoriano/stroke-prediction-dataset/versions/1

# %%
os.listdir(path)
# Out:
# ['healthcare-dataset-stroke-data.csv']

# %% [markdown]
# # Read the Dataset

# %%
df=pd.read_csv(path+'/healthcare-dataset-stroke-data.csv')
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# # **Data Preprocessing & EDA**

# %%
df.rename(columns={'heart_disease':"heart disease","ever_married":"Married","avg_glucose_level":"Avg_Glucose_Level","smoking_status":"Smoking Status","work_type":"Work Type"},inplace=True)

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart disease Married      Work Type  \
# 0   9046    Male  67.0             0              1     Yes        Private
# 1  51676  Female  61.0             0              0     Yes  Self-employed
# 2  31112    Male  80.0             0              1     Yes        Private
# 3  60182  Female  49.0             0              0     Yes        Private
# 4   1665  Female  79.0             1              0     Yes  Self-employed
#
#   Residence_type  Avg_Glucose_Level   bmi   Smoking Status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df.drop('id',axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender   age  hypertension  heart disease Married      Work Type  \
# 0    Male  67.0             0              1     Yes        Private
# 1  Female  61.0             0              0     Yes  Self-employed
# 2    Male  80.0             0              1     Yes        Private
# 3  Female  49.0             0              0     Yes        Private
# 4  Female  79.0             1              0     Yes  Self-employed
#
#   Residence_type  Avg_Glucose_Level   bmi   Smoking Status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21   NaN     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %%
df.shape
# Out:
# (5110, 11)

# %%
df.isnull().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart disease          0
# Married                0
# Work Type              0
# Residence_type         0
# Avg_Glucose_Level      0
# bmi                  201
# Smoking Status         0
# stroke                 0
# dtype: int64

# %%
df = df[df['gender'] != 'Other']
df['gender'].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Name: count, dtype: int64

# %%
sns.histplot(df['bmi'],kde=True)
plt.show()

# %%
df['bmi'].skew()
# Out:
# np.float64(1.0550629490426457)

# %%
df['bmi'].mean()
# Out:
# np.float64(28.894559902200488)

# %%
df['bmi'].median()
# Out:
# 28.1

# %%
df.fillna(df['bmi'].median(),inplace=True)

# %%
df['bmi'].isnull().sum()
# Out:
# np.int64(0)

# %%
sns.histplot(df['bmi'],kde=True)
plt.show()

# %%
df.isnull().sum()
# Out:
# gender               0
# age                  0
# hypertension         0
# heart disease        0
# Married              0
# Work Type            0
# Residence_type       0
# Avg_Glucose_Level    0
# bmi                  0
# Smoking Status       0
# stroke               0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(5)
# Out:
#       gender    age  hypertension  heart disease Married      Work Type  \
# 2975  Female  33.00             0              0     Yes        Private
# 4645  Female   0.48             0              0      No       children
# 807   Female  51.00             0              0      No       Govt_job
# 4711    Male  79.00             0              0     Yes  Self-employed
# 2588    Male   6.00             0              0      No       children
#
#      Residence_type  Avg_Glucose_Level   bmi Smoking Status  stroke
# 2975          Rural             114.16  43.3   never smoked       0
# 4645          Rural              94.06  14.8        Unknown       0
# 807           Rural             116.14  20.9   never smoked       0
# 4711          Urban             242.62  25.5   never smoked       0
# 2588          Rural              79.05  17.9        Unknown       0

# %%
df.dtypes
# Out:
# gender                object
# age                  float64
# hypertension           int64
# heart disease          int64
# Married               object
# Work Type             object
# Residence_type        object
# Avg_Glucose_Level    float64
# bmi                  float64
# Smoking Status        object
# stroke                 int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5109 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5109 non-null   object
#  1   age                5109 non-null   float64
#  2   hypertension       5109 non-null   int64
#  3   heart disease      5109 non-null   int64
#  4   Married            5109 non-null   object
#  5   Work Type          5109 non-null   object
#  6   Residence_type     5109 non-null   object
#  7   Avg_Glucose_Level  5109 non-null   float64
#  8   bmi                5109 non-null   float64
#  9   Smoking Status     5109 non-null   object
#  10  stroke             5109 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 479.0+ KB

# %%
df.describe()
# Out:
#                age  hypertension  heart disease  Avg_Glucose_Level  \
# count  5109.000000   5109.000000    5109.000000        5109.000000
# mean     43.229986      0.097475       0.054022         106.140399
# std      22.613575      0.296633       0.226084          45.285004
# min       0.080000      0.000000       0.000000          55.120000
# 25%      25.000000      0.000000       0.000000          77.240000
# 50%      45.000000      0.000000       0.000000          91.880000
# 75%      61.000000      0.000000       0.000000         114.090000
# max      82.000000      1.000000       1.000000         271.740000
#
#                bmi       stroke
# count  5109.000000  5109.000000
# mean     28.863300     0.048738
# std       7.699785     0.215340
# min      10.300000     0.000000
# 25%      23.800000     0.000000
# 50%      28.100000     0.000000
# 75%      32.800000     0.000000
# max      97.600000     1.000000

# %%
df['age']=df['age'].astype("int64")

# %%
df["age"].head()
# Out:
# 0    67
# 1    61
# 2    80
# 3    49
# 4    79
# Name: age, dtype: int64

# %% [markdown]
# # Check All Unique Values

# %%
df['stroke'].value_counts()
# Out:
# stroke
# 0    4860
# 1     249
# Name: count, dtype: int64

# %%
df['Married'].value_counts()
# Out:
# Married
# Yes    3353
# No     1756
# Name: count, dtype: int64

# %%
df['Smoking Status'].value_counts()
# Out:
# Smoking Status
# never smoked       1892
# Unknown            1544
# formerly smoked     884
# smokes              789
# Name: count, dtype: int64

# %%
df['gender'].value_counts()
# Out:
# gender
# Female    2994
# Male      2115
# Name: count, dtype: int64

# %%
df['heart disease'].value_counts()
# Out:
# heart disease
# 0    4833
# 1     276
# Name: count, dtype: int64

# %%
df['hypertension'].value_counts()
# Out:
# hypertension
# 0    4611
# 1     498
# Name: count, dtype: int64

# %%
df['Work Type'].value_counts()
# Out:
# Work Type
# Private          2924
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: count, dtype: int64

# %%
df['Residence_type'].value_counts()
# Out:
# Residence_type
# Urban    2596
# Rural    2513
# Name: count, dtype: int64

# %%
df['Avg_Glucose_Level'].unique()
# Out:
# array([228.69, 202.21, 105.92, ...,  82.99, 166.29,  85.28])

# %%
df['age'].unique()
# Out:
# array([67, 61, 80, 49, 79, 81, 74, 69, 59, 78, 54, 50, 64, 75, 60, 57, 71,
#        52, 82, 65, 58, 42, 48, 72, 63, 76, 39, 77, 73, 56, 45, 70, 66, 51,
#        43, 68, 47, 53, 38, 55,  1, 46, 32, 14,  3,  8, 37, 40, 35, 20, 44,
#        25, 27, 23, 17, 13,  4, 16, 22, 30, 29, 11, 21, 18, 33, 24, 34, 36,
#         0, 41,  5, 26, 31,  7, 12, 62,  2,  9, 15, 28, 10, 19,  6])

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='stroke',data=df)
plt.title('Count of stroke',color='red',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.countplot(x='stroke',data=df,hue='gender',palette='plasma')
plt.title('Count of stroke',color='red',fontsize=15)
plt.show()

# %%
plt.pie(df['stroke'].value_counts(),labels=['No','Yes'],autopct='%.2f%%',colors=["#F86363","#A6FA8F"],radius=1.1,shadow=True)
plt.title('Count of stroke',color='red',fontsize=15)
plt.show()

# %%
sns.histplot(df['age'],kde=True)
plt.show()

# %%
sns.barplot(y='age',x='stroke',data=df,hue="gender",palette='deep')
plt.title('Count of stroke',color='red',fontsize=15)
plt.show()

# %%
plt.pie(df['hypertension'].value_counts(),labels=['No','Yes'],autopct='%.2f%%',colors=["#8FFAD6","#8FE1FA"],radius=1.1,shadow=True)
plt.title('Hypertension',color='red',fontsize=15)
plt.show()

# %%
sns.barplot(y='age',x='hypertension',data=df,hue="gender",palette='coolwarm')
plt.title('Hypertension vs Age',color='red',fontsize=15)
plt.show()

# %%
sns.histplot(df['Avg_Glucose_Level'],kde=True)
plt.title('Avg_Glucose_Level',color='red',fontsize=15)
plt.show()

# %%
sns.barplot(y='age',x='heart disease',data=df,hue="gender",palette='colorblind')
plt.title('Hypertension vs Age',color='red',fontsize=15)
plt.show()

# %%
plt.pie(df['Work Type'].value_counts(),labels=df["Work Type"].value_counts().index,autopct='%.2f%%',colors=["#D5F863","#F1BBFC","#FA8FC3","#F86386","#F8B063"],radius=1.1,shadow=True)
plt.title('Work Type',color='red',fontsize=15)
plt.show()

# %%
sns.barplot(y='Avg_Glucose_Level',x='gender',data=df,hue="stroke",palette='muted')
plt.title('Avg_Glucose_Level Vs Stroke',color='red',fontsize=15)
plt.show()

# %%
plt.pie(df['Smoking Status'].value_counts(),labels=df["Smoking Status"].value_counts().index,autopct='%.2f%%',colors=["#DCF863","#F86386","#F8C663","#8FFADF"],radius=1.1,shadow=True)
plt.title('Smoking Status',color='red',fontsize=15)
plt.show()

# %%
sns.barplot(x='Work Type',y='Avg_Glucose_Level',data=df,hue="stroke",palette='Spectral')
plt.title('Hypertension Vs Age',color='red',fontsize=15)
plt.show()

# %%
sns.barplot(y='age',x='heart disease',data=df,hue="stroke",palette='BrBG')
plt.title('Heart Disease Vs Age',color='red',fontsize=15)
plt.show()

# %%
sns.scatterplot(data=df,x="bmi",y="Avg_Glucose_Level",color='blue',marker="o",hue="stroke")
plt.title('Bmi Vs Avg_Glucose_Level',color='red',fontsize=15)
plt.show()

# %%
plt.pie(df['heart disease'].value_counts(),labels=['No','Yes'],autopct='%.2f%%',colors=["#8FFAAA","#F86386"],radius=1.1,shadow=True)
plt.title('heart disease',color='red',fontsize=15)
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.histplot(df['bmi'],kde=True)
plt.title('bmi',color='red',fontsize=15)
plt.show()

# %%
sns.lineplot(data=df,x="bmi",y="age",color='red')
plt.title('bmi Vs Age',color='red',fontsize=15)
plt.show()

# %%
plt.pie(df['Married'].value_counts(),labels=df["Married"].value_counts().index,autopct='%.2f%%',colors=["#F86386","#8FFADF"],radius=1.1,shadow=True)
plt.title('Married',color='red',fontsize=15)
plt.show()

# %%
sns.barplot(y='age',x='Residence_type',data=df,hue="stroke",palette='PiYG')
plt.title('Heart Disease Vs Age',color='red',fontsize=15)
plt.show()

# %%
plt.pie(df['Smoking Status'].value_counts(),labels=df["Smoking Status"].value_counts().index,autopct='%.2f%%',colors=["#DCF863","#F86386","#F8C663","#8FFADF"],radius=1.1,shadow=True)
plt.title('Smoking Status',color='red',fontsize=15)
plt.show()

# %%
sns.pairplot(df,hue="stroke")
plt.title('Pairplot',color='red',fontsize=15)
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
plt.title('Correlation',color='red',fontsize=15)
plt.show()

# %% [markdown]
# # Data Encoding And Scaling

# %%
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder,OneHotEncoder,StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.compose import make_column_transformer
from sklearn.pipeline import Pipeline

# %% [markdown]
# # Split X and Y

# %%
x=df.drop(columns=["stroke"],axis=1)
y=df["stroke"]

# %%
ohe=OneHotEncoder(handle_unknown='ignore')
ohe.fit(x[["gender","Married","Work Type","Residence_type","Smoking Status"]])
# Out:
# OneHotEncoder(handle_unknown='ignore')

# %%
ss=StandardScaler()
ss.fit(x[["age","Avg_Glucose_Level","bmi","heart disease","hypertension"]])
# Out:
# StandardScaler()

# %%
df.head()
# Out:
#    gender  age  hypertension  heart disease Married      Work Type  \
# 0    Male   67             0              1     Yes        Private
# 1  Female   61             0              0     Yes  Self-employed
# 2    Male   80             0              1     Yes        Private
# 3  Female   49             0              0     Yes        Private
# 4  Female   79             1              0     Yes  Self-employed
#
#   Residence_type  Avg_Glucose_Level   bmi   Smoking Status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21  28.1     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1

# %% [markdown]
# # Train Test Split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Fill Nan Values

# %%
median_bmi = x_train['bmi'].median()
x_train['bmi'].fillna(median_bmi, inplace=True)
x_test['bmi'].fillna(median_bmi, inplace=True)
# Out:
# /tmp/ipykernel_2986/3066497001.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_train['bmi'].fillna(median_bmi, inplace=True)
# /tmp/ipykernel_2986/3066497001.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   x_test['bmi'].fillna(median_bmi, inplace=True)

# %%
column_trans=make_column_transformer(
    (ohe,["gender","Married","Work Type","Residence_type","Smoking Status"]),
    (ss,["age","Avg_Glucose_Level","bmi","heart disease","hypertension"]),
    remainder="passthrough"
)

# %%
column_trans
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['gender', 'Married', 'Work Type',
#                                   'Residence_type', 'Smoking Status']),
#                                 ('standardscaler', StandardScaler(),
#                                  ['age', 'Avg_Glucose_Level', 'bmi',
#                                   'heart disease', 'hypertension'])])

# %%
x_train_tranform=column_trans.fit_transform(x_train)
x_test_transform=column_trans.transform(x_test)

# %%
# from imblearn.over_sampling import SMOTE
# oversample = SMOTE(random_state=42)
# X_train_resh, y_train_resh = oversample.fit_resample(x_train_tranform, y_train)

# %% [markdown]
# # Balance the Data using ADASYN

# %%
from imblearn.over_sampling import ADASYN
adasyn = ADASYN(random_state=42)
X_res, y_res = adasyn.fit_resample(x_train_tranform, y_train)

# %%
x_train
# Out:
#       gender  age  hypertension  heart disease Married      Work Type  \
# 802     Male   79             0              0     Yes  Self-employed
# 3927  Female   62             0              0     Yes        Private
# 2337  Female   21             0              0      No        Private
# 3910    Male   31             0              0     Yes       Govt_job
# 1886  Female   31             0              0      No        Private
# ...      ...  ...           ...            ...     ...            ...
# 4427  Female   61             0              0     Yes        Private
# 466   Female   61             1              0     Yes        Private
# 3092  Female    1             0              0      No       children
# 3773  Female   38             0              0     Yes       Govt_job
# 860   Female   46             0              0     Yes        Private
#
#      Residence_type  Avg_Glucose_Level   bmi   Smoking Status
# 802           Rural             112.64  28.5  formerly smoked
# 3927          Urban              88.32  36.3          Unknown
# 2337          Rural              59.52  33.7     never smoked
# 3910          Urban              65.70  30.4  formerly smoked
# 1886          Rural              59.63  19.9     never smoked
# ...             ...                ...   ...              ...
# 4427          Rural             144.14  29.8     never smoked
# 466           Rural             170.05  60.2           smokes
# 3092          Urban              97.28  17.8          Unknown
# 3773          Rural              93.93  21.5     never smoked
# 860           Rural             100.15  50.3           smokes
#
# [4087 rows x 10 columns]

# %%
x.head()
# Out:
#    gender  age  hypertension  heart disease Married      Work Type  \
# 0    Male   67             0              1     Yes        Private
# 1  Female   61             0              0     Yes  Self-employed
# 2    Male   80             0              1     Yes        Private
# 3  Female   49             0              0     Yes        Private
# 4  Female   79             1              0     Yes  Self-employed
#
#   Residence_type  Avg_Glucose_Level   bmi   Smoking Status
# 0          Urban             228.69  36.6  formerly smoked
# 1          Rural             202.21  28.1     never smoked
# 2          Rural             105.92  32.5     never smoked
# 3          Urban             171.23  34.4           smokes
# 4          Rural             174.12  24.0     never smoked

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: stroke, dtype: int64

# %%
x.shape
# Out:
# (5109, 10)

# %%
y.shape
# Out:
# (5109,)

# %%
# X_train_resh.shape

# %%
pd.Series(y_train).value_counts()
# Out:
# stroke
# 0    3900
# 1     187
# Name: count, dtype: int64

# %%
# pd.Series(y_train_resh).value_counts()

# %% [markdown]
# # **Data Modeling With Artifical Neural Network (ANN) Architecture**

# %% [markdown]
# # Import Tensorflow Library

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout

# %%
# Dropout randomly turns off neurons during training.


model = tf.keras.Sequential([
    # Input Layers
    tf.keras.layers.InputLayer(input_shape=(X_res.shape[1],)),


    # dense Layers
    tf.keras.layers.Dense(64, activation='relu'),
    tf.keras.layers.Dense(32, activation='relu'),



    # Output Layers
    tf.keras.layers.Dense(1, activation='sigmoid')
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(

# %% [markdown]
# # Model Summary

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,457 (13.50 KB)
#  Trainable params: 3,457 (13.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.metrics import F1Score,Accuracy,Precision,Recall,AUC
from tensorflow.keras.callbacks import EarlyStopping

# %%
model.compile(
  optimizer='adam',
  loss='binary_crossentropy',
  metrics=['accuracy','Precision','Recall','f1_score']
)

# %% [markdown]
# # **Early Stoping:**
# Early Stopping is a technique used in machine learning and deep learning (including TensorFlow) to stop training automatically when the model stops improving on validation data

# %%
# early stopping
early_stop = EarlyStopping(
    monitor='val_recall',
    patience=5,
    mode='max',
    restore_best_weights=True
)

# %% [markdown]
# ## 📊 **Model Performance Interpretation Theory**
#
# ### 🔴 1. Training accuracy >> Validation accuracy
#
# This indicates **overfitting**.
# The model performs very well on training data but poorly on unseen validation data, meaning it has memorized the training data instead of learning general patterns.
#
# ---
#
# ### 🟡 2. Training accuracy << Validation accuracy
#
# This is uncommon and may indicate **underfitting or data mismatch**.
# The model is not learning the training data properly, or validation data may be easier than training data.
#
# ---
#
# ### 🟢 3. Training accuracy ≈ Validation accuracy
#
# This indicates a **well-balanced model (good fit)**.
# The model has learned general patterns and performs consistently on both training and validation data, showing good generalization.
#
# ---

# %%
# from sklearn.utils import class_weight
# # compute weights

# weights = class_weight.compute_class_weight(
#     class_weight='balanced',
#     classes=np.unique(y_train),
#     y=y_train
# )

# class_weights = {
#     0:1,   # majority class
#     1:19.5    # minority class (increase importance)
# }

# %%
history = model.fit(
    X_res,
    y_res,
    epochs=100,
    batch_size=32,
    validation_split=0.2,
    # class_weight=class_weights,
    callbacks=[early_stop]


)
# Out:
# Epoch 1/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - Precision: 0.6938 - Recall: 0.6558 - accuracy: 0.7616 - f1_score: 0.5468 - loss: 0.4833 - val_Precision: 1.0000 - val_Recall: 0.7219 - val_accuracy: 0.7219 - val_f1_score: 1.0000 - val_loss: 0.6344
# Epoch 2/100
#  81/196 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Precision: 0.7361 - Recall: 0.7426 - accuracy: 0.7994 - f1_score: 0.5524 - loss: 0.4258
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/early_stopping.py:99: UserWarning: Early stopping conditioned on metric `val_recall` which is not available. Available metrics are: Precision,Recall,accuracy,f1_score,loss,val_Precision,val_Recall,val_accuracy,val_f1_score,val_loss
#   current = self.get_monitor_value(logs)
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.7239 - Recall: 0.7709 - accuracy: 0.8031 - f1_score: 0.5468 - loss: 0.4128 - val_Precision: 1.0000 - val_Recall: 0.6861 - val_accuracy: 0.6861 - val_f1_score: 1.0000 - val_loss: 0.6688
# Epoch 3/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.7558 - Recall: 0.8062 - accuracy: 0.8290 - f1_score: 0.5468 - loss: 0.3804 - val_Precision: 1.0000 - val_Recall: 0.6637 - val_accuracy: 0.6637 - val_f1_score: 1.0000 - val_loss: 0.7041
# Epoch 4/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.7763 - Recall: 0.8228 - accuracy: 0.8441 - f1_score: 0.5468 - loss: 0.3502 - val_Precision: 1.0000 - val_Recall: 0.7148 - val_accuracy: 0.7148 - val_f1_score: 1.0000 - val_loss: 0.6267
# Epoch 5/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.7925 - Recall: 0.8504 - accuracy: 0.8599 - f1_score: 0.5468 - loss: 0.3245 - val_Precision: 1.0000 - val_Recall: 0.7276 - val_accuracy: 0.7276 - val_f1_score: 1.0000 - val_loss: 0.5995
# Epoch 6/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8130 - Recall: 0.8627 - accuracy: 0.8737 - f1_score: 0.5468 - loss: 0.3032 - val_Precision: 1.0000 - val_Recall: 0.7391 - val_accuracy: 0.7391 - val_f1_score: 1.0000 - val_loss: 0.5870
# Epoch 7/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.8149 - Recall: 0.8776 - accuracy: 0.8789 - f1_score: 0.5468 - loss: 0.2876 - val_Precision: 1.0000 - val_Recall: 0.7532 - val_accuracy: 0.7532 - val_f1_score: 1.0000 - val_loss: 0.5864
# Epoch 8/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.8256 - Recall: 0.8870 - accuracy: 0.8869 - f1_score: 0.5469 - loss: 0.2715 - val_Precision: 1.0000 - val_Recall: 0.6957 - val_accuracy: 0.6957 - val_f1_score: 1.0000 - val_loss: 0.6458
# Epoch 9/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.8314 - Recall: 0.8989 - accuracy: 0.8933 - f1_score: 0.5469 - loss: 0.2633 - val_Precision: 1.0000 - val_Recall: 0.6790 - val_accuracy: 0.6790 - val_f1_score: 1.0000 - val_loss: 0.6803
# Epoch 10/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8412 - Recall: 0.8963 - accuracy: 0.8973 - f1_score: 0.5470 - loss: 0.2478 - val_Precision: 1.0000 - val_Recall: 0.7283 - val_accuracy: 0.7283 - val_f1_score: 1.0000 - val_loss: 0.5735
# Epoch 11/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8453 - Recall: 0.9057 - accuracy: 0.9021 - f1_score: 0.5470 - loss: 0.2376 - val_Precision: 1.0000 - val_Recall: 0.6432 - val_accuracy: 0.6432 - val_f1_score: 1.0000 - val_loss: 0.7370
# Epoch 12/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8548 - Recall: 0.9035 - accuracy: 0.9060 - f1_score: 0.5471 - loss: 0.2301 - val_Precision: 1.0000 - val_Recall: 0.8043 - val_accuracy: 0.8043 - val_f1_score: 1.0000 - val_loss: 0.4763
# Epoch 13/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8596 - Recall: 0.9159 - accuracy: 0.9120 - f1_score: 0.5473 - loss: 0.2198 - val_Precision: 1.0000 - val_Recall: 0.7864 - val_accuracy: 0.7864 - val_f1_score: 1.0000 - val_loss: 0.5382
# Epoch 14/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8670 - Recall: 0.9171 - accuracy: 0.9159 - f1_score: 0.5475 - loss: 0.2118 - val_Precision: 1.0000 - val_Recall: 0.7506 - val_accuracy: 0.7506 - val_f1_score: 1.0000 - val_loss: 0.5962
# Epoch 15/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8658 - Recall: 0.9269 - accuracy: 0.9184 - f1_score: 0.5484 - loss: 0.2068 - val_Precision: 1.0000 - val_Recall: 0.5396 - val_accuracy: 0.5396 - val_f1_score: 1.0000 - val_loss: 0.9537
# Epoch 16/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8798 - Recall: 0.9235 - accuracy: 0.9237 - f1_score: 0.5494 - loss: 0.1991 - val_Precision: 1.0000 - val_Recall: 0.7590 - val_accuracy: 0.7590 - val_f1_score: 1.0000 - val_loss: 0.4897
# Epoch 17/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8807 - Recall: 0.9256 - accuracy: 0.9248 - f1_score: 0.5499 - loss: 0.1908 - val_Precision: 1.0000 - val_Recall: 0.6592 - val_accuracy: 0.6592 - val_f1_score: 1.0000 - val_loss: 0.7002
# Epoch 18/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8801 - Recall: 0.9265 - accuracy: 0.9248 - f1_score: 0.5509 - loss: 0.1847 - val_Precision: 1.0000 - val_Recall: 0.7219 - val_accuracy: 0.7219 - val_f1_score: 1.0000 - val_loss: 0.5912
# Epoch 19/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8874 - Recall: 0.9307 - accuracy: 0.9295 - f1_score: 0.5516 - loss: 0.1801 - val_Precision: 1.0000 - val_Recall: 0.7980 - val_accuracy: 0.7980 - val_f1_score: 1.0000 - val_loss: 0.4805
# Epoch 20/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8900 - Recall: 0.9320 - accuracy: 0.9311 - f1_score: 0.5527 - loss: 0.1739 - val_Precision: 1.0000 - val_Recall: 0.8286 - val_accuracy: 0.8286 - val_f1_score: 1.0000 - val_loss: 0.4187
# Epoch 21/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8940 - Recall: 0.9388 - accuracy: 0.9351 - f1_score: 0.5535 - loss: 0.1686 - val_Precision: 1.0000 - val_Recall: 0.7558 - val_accuracy: 0.7558 - val_f1_score: 1.0000 - val_loss: 0.5278
# Epoch 22/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8964 - Recall: 0.9375 - accuracy: 0.9357 - f1_score: 0.5546 - loss: 0.1634 - val_Precision: 1.0000 - val_Recall: 0.7756 - val_accuracy: 0.7756 - val_f1_score: 1.0000 - val_loss: 0.5090
# Epoch 23/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.8982 - Recall: 0.9380 - accuracy: 0.9367 - f1_score: 0.5557 - loss: 0.1614 - val_Precision: 1.0000 - val_Recall: 0.8792 - val_accuracy: 0.8792 - val_f1_score: 1.0000 - val_loss: 0.3277
# Epoch 24/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9078 - Recall: 0.9452 - accuracy: 0.9432 - f1_score: 0.5581 - loss: 0.1560 - val_Precision: 1.0000 - val_Recall: 0.8082 - val_accuracy: 0.8082 - val_f1_score: 1.0000 - val_loss: 0.4861
# Epoch 25/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9038 - Recall: 0.9507 - accuracy: 0.9434 - f1_score: 0.5591 - loss: 0.1511 - val_Precision: 1.0000 - val_Recall: 0.8024 - val_accuracy: 0.8024 - val_f1_score: 1.0000 - val_loss: 0.4998
# Epoch 26/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9088 - Recall: 0.9448 - accuracy: 0.9435 - f1_score: 0.5610 - loss: 0.1468 - val_Precision: 1.0000 - val_Recall: 0.8606 - val_accuracy: 0.8606 - val_f1_score: 1.0000 - val_loss: 0.3556
# Epoch 27/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.9072 - Recall: 0.9477 - accuracy: 0.9439 - f1_score: 0.5617 - loss: 0.1426 - val_Precision: 1.0000 - val_Recall: 0.7641 - val_accuracy: 0.7641 - val_f1_score: 1.0000 - val_loss: 0.5454
# Epoch 28/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Precision: 0.9149 - Recall: 0.9507 - accuracy: 0.9482 - f1_score: 0.5647 - loss: 0.1418 - val_Precision: 1.0000 - val_Recall: 0.8868 - val_accuracy: 0.8868 - val_f1_score: 1.0000 - val_loss: 0.2998
# Epoch 29/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.9142 - Recall: 0.9511 - accuracy: 0.9480 - f1_score: 0.5634 - loss: 0.1365 - val_Precision: 1.0000 - val_Recall: 0.6950 - val_accuracy: 0.6950 - val_f1_score: 1.0000 - val_loss: 0.6846
# Epoch 30/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9201 - Recall: 0.9490 - accuracy: 0.9498 - f1_score: 0.5651 - loss: 0.1339 - val_Precision: 1.0000 - val_Recall: 0.9297 - val_accuracy: 0.9297 - val_f1_score: 1.0000 - val_loss: 0.2097
# Epoch 31/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9182 - Recall: 0.9592 - accuracy: 0.9525 - f1_score: 0.5672 - loss: 0.1314 - val_Precision: 1.0000 - val_Recall: 0.8632 - val_accuracy: 0.8632 - val_f1_score: 1.0000 - val_loss: 0.3469
# Epoch 32/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9199 - Recall: 0.9567 - accuracy: 0.9523 - f1_score: 0.5691 - loss: 0.1282 - val_Precision: 1.0000 - val_Recall: 0.8542 - val_accuracy: 0.8542 - val_f1_score: 1.0000 - val_loss: 0.3517
# Epoch 33/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9229 - Recall: 0.9567 - accuracy: 0.9536 - f1_score: 0.5701 - loss: 0.1270 - val_Precision: 1.0000 - val_Recall: 0.8574 - val_accuracy: 0.8574 - val_f1_score: 1.0000 - val_loss: 0.3678
# Epoch 34/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9287 - Recall: 0.9584 - accuracy: 0.9567 - f1_score: 0.5727 - loss: 0.1235 - val_Precision: 1.0000 - val_Recall: 0.8306 - val_accuracy: 0.8306 - val_f1_score: 1.0000 - val_loss: 0.3730
# Epoch 35/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9320 - Recall: 0.9545 - accuracy: 0.9567 - f1_score: 0.5731 - loss: 0.1218 - val_Precision: 1.0000 - val_Recall: 0.8434 - val_accuracy: 0.8434 - val_f1_score: 1.0000 - val_loss: 0.3651
# Epoch 36/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9205 - Recall: 0.9596 - accuracy: 0.9536 - f1_score: 0.5752 - loss: 0.1189 - val_Precision: 1.0000 - val_Recall: 0.8600 - val_accuracy: 0.8600 - val_f1_score: 1.0000 - val_loss: 0.3408
# Epoch 37/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9322 - Recall: 0.9579 - accuracy: 0.9579 - f1_score: 0.5762 - loss: 0.1160 - val_Precision: 1.0000 - val_Recall: 0.8561 - val_accuracy: 0.8561 - val_f1_score: 1.0000 - val_loss: 0.3405
# Epoch 38/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9359 - Recall: 0.9618 - accuracy: 0.9608 - f1_score: 0.5788 - loss: 0.1133 - val_Precision: 1.0000 - val_Recall: 0.8900 - val_accuracy: 0.8900 - val_f1_score: 1.0000 - val_loss: 0.2491
# Epoch 39/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9319 - Recall: 0.9652 - accuracy: 0.9603 - f1_score: 0.5793 - loss: 0.1100 - val_Precision: 1.0000 - val_Recall: 0.8395 - val_accuracy: 0.8395 - val_f1_score: 1.0000 - val_loss: 0.3787
# Epoch 40/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9373 - Recall: 0.9656 - accuracy: 0.9627 - f1_score: 0.5811 - loss: 0.1092 - val_Precision: 1.0000 - val_Recall: 0.8549 - val_accuracy: 0.8549 - val_f1_score: 1.0000 - val_loss: 0.3178
# Epoch 41/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9324 - Recall: 0.9613 - accuracy: 0.9592 - f1_score: 0.5835 - loss: 0.1061 - val_Precision: 1.0000 - val_Recall: 0.9220 - val_accuracy: 0.9220 - val_f1_score: 1.0000 - val_loss: 0.2098
# Epoch 42/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9374 - Recall: 0.9677 - accuracy: 0.9635 - f1_score: 0.5839 - loss: 0.1069 - val_Precision: 1.0000 - val_Recall: 0.8242 - val_accuracy: 0.8242 - val_f1_score: 1.0000 - val_loss: 0.3999
# Epoch 43/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9353 - Recall: 0.9647 - accuracy: 0.9616 - f1_score: 0.5857 - loss: 0.1030 - val_Precision: 1.0000 - val_Recall: 0.8542 - val_accuracy: 0.8542 - val_f1_score: 1.0000 - val_loss: 0.3341
# Epoch 44/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9377 - Recall: 0.9652 - accuracy: 0.9627 - f1_score: 0.5875 - loss: 0.1019 - val_Precision: 1.0000 - val_Recall: 0.9508 - val_accuracy: 0.9508 - val_f1_score: 1.0000 - val_loss: 0.1408
# Epoch 45/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9398 - Recall: 0.9626 - accuracy: 0.9627 - f1_score: 0.5897 - loss: 0.1023 - val_Precision: 1.0000 - val_Recall: 0.8702 - val_accuracy: 0.8702 - val_f1_score: 1.0000 - val_loss: 0.2764
# Epoch 46/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9395 - Recall: 0.9635 - accuracy: 0.9629 - f1_score: 0.5893 - loss: 0.0989 - val_Precision: 1.0000 - val_Recall: 0.7973 - val_accuracy: 0.7973 - val_f1_score: 1.0000 - val_loss: 0.4241
# Epoch 47/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.9450 - Recall: 0.9635 - accuracy: 0.9651 - f1_score: 0.5907 - loss: 0.0981 - val_Precision: 1.0000 - val_Recall: 0.9124 - val_accuracy: 0.9124 - val_f1_score: 1.0000 - val_loss: 0.2323
# Epoch 48/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Precision: 0.9426 - Recall: 0.9698 - accuracy: 0.9664 - f1_score: 0.5935 - loss: 0.0955 - val_Precision: 1.0000 - val_Recall: 0.9233 - val_accuracy: 0.9233 - val_f1_score: 1.0000 - val_loss: 0.2034
# Epoch 49/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - Precision: 0.9432 - Recall: 0.9677 - accuracy: 0.9659 - f1_score: 0.5952 - loss: 0.0944 - val_Precision: 1.0000 - val_Recall: 0.8696 - val_accuracy: 0.8696 - val_f1_score: 1.0000 - val_loss: 0.2831
# Epoch 50/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9403 - Recall: 0.9707 - accuracy: 0.9658 - f1_score: 0.5961 - loss: 0.0949 - val_Precision: 1.0000 - val_Recall: 0.8676 - val_accuracy: 0.8676 - val_f1_score: 1.0000 - val_loss: 0.3176
# Epoch 51/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9422 - Recall: 0.9703 - accuracy: 0.9664 - f1_score: 0.5965 - loss: 0.0920 - val_Precision: 1.0000 - val_Recall: 0.9156 - val_accuracy: 0.9156 - val_f1_score: 1.0000 - val_loss: 0.2197
# Epoch 52/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9440 - Recall: 0.9677 - accuracy: 0.9663 - f1_score: 0.5999 - loss: 0.0883 - val_Precision: 1.0000 - val_Recall: 0.8919 - val_accuracy: 0.8919 - val_f1_score: 1.0000 - val_loss: 0.2622
# Epoch 53/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9456 - Recall: 0.9669 - accuracy: 0.9666 - f1_score: 0.6023 - loss: 0.0909 - val_Precision: 1.0000 - val_Recall: 0.8875 - val_accuracy: 0.8875 - val_f1_score: 1.0000 - val_loss: 0.2614
# Epoch 54/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9475 - Recall: 0.9664 - accuracy: 0.9672 - f1_score: 0.6059 - loss: 0.0888 - val_Precision: 1.0000 - val_Recall: 0.9591 - val_accuracy: 0.9591 - val_f1_score: 1.0000 - val_loss: 0.1266
# Epoch 55/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9491 - Recall: 0.9669 - accuracy: 0.9680 - f1_score: 0.6036 - loss: 0.0920 - val_Precision: 1.0000 - val_Recall: 0.9386 - val_accuracy: 0.9386 - val_f1_score: 1.0000 - val_loss: 0.1657
# Epoch 56/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9470 - Recall: 0.9715 - accuracy: 0.9688 - f1_score: 0.6036 - loss: 0.0852 - val_Precision: 1.0000 - val_Recall: 0.9329 - val_accuracy: 0.9329 - val_f1_score: 1.0000 - val_loss: 0.1771
# Epoch 57/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9474 - Recall: 0.9720 - accuracy: 0.9691 - f1_score: 0.6047 - loss: 0.0839 - val_Precision: 1.0000 - val_Recall: 0.9297 - val_accuracy: 0.9297 - val_f1_score: 1.0000 - val_loss: 0.1974
# Epoch 58/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9478 - Recall: 0.9724 - accuracy: 0.9695 - f1_score: 0.6047 - loss: 0.0858 - val_Precision: 1.0000 - val_Recall: 0.9047 - val_accuracy: 0.9047 - val_f1_score: 1.0000 - val_loss: 0.2497
# Epoch 59/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9512 - Recall: 0.9694 - accuracy: 0.9698 - f1_score: 0.6061 - loss: 0.0814 - val_Precision: 1.0000 - val_Recall: 0.7864 - val_accuracy: 0.7864 - val_f1_score: 1.0000 - val_loss: 0.4654
# Epoch 60/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9541 - Recall: 0.9715 - accuracy: 0.9717 - f1_score: 0.6075 - loss: 0.0796 - val_Precision: 1.0000 - val_Recall: 0.9098 - val_accuracy: 0.9098 - val_f1_score: 1.0000 - val_loss: 0.2126
# Epoch 61/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9541 - Recall: 0.9707 - accuracy: 0.9714 - f1_score: 0.6086 - loss: 0.0806 - val_Precision: 1.0000 - val_Recall: 0.9143 - val_accuracy: 0.9143 - val_f1_score: 1.0000 - val_loss: 0.2324
# Epoch 62/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9497 - Recall: 0.9711 - accuracy: 0.9698 - f1_score: 0.6110 - loss: 0.0807 - val_Precision: 1.0000 - val_Recall: 0.8408 - val_accuracy: 0.8408 - val_f1_score: 1.0000 - val_loss: 0.3366
# Epoch 63/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9554 - Recall: 0.9749 - accuracy: 0.9735 - f1_score: 0.6122 - loss: 0.0777 - val_Precision: 1.0000 - val_Recall: 0.9501 - val_accuracy: 0.9501 - val_f1_score: 1.0000 - val_loss: 0.1456
# Epoch 64/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9530 - Recall: 0.9745 - accuracy: 0.9723 - f1_score: 0.6124 - loss: 0.0736 - val_Precision: 1.0000 - val_Recall: 0.9393 - val_accuracy: 0.9393 - val_f1_score: 1.0000 - val_loss: 0.1654
# Epoch 65/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9526 - Recall: 0.9732 - accuracy: 0.9717 - f1_score: 0.6133 - loss: 0.0776 - val_Precision: 1.0000 - val_Recall: 0.8382 - val_accuracy: 0.8382 - val_f1_score: 1.0000 - val_loss: 0.3175
# Epoch 66/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9527 - Recall: 0.9681 - accuracy: 0.9699 - f1_score: 0.6162 - loss: 0.0780 - val_Precision: 1.0000 - val_Recall: 0.9367 - val_accuracy: 0.9367 - val_f1_score: 1.0000 - val_loss: 0.1732
# Epoch 67/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9578 - Recall: 0.9749 - accuracy: 0.9744 - f1_score: 0.6136 - loss: 0.0739 - val_Precision: 1.0000 - val_Recall: 0.9425 - val_accuracy: 0.9425 - val_f1_score: 1.0000 - val_loss: 0.1649
# Epoch 68/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.9513 - Recall: 0.9711 - accuracy: 0.9704 - f1_score: 0.6167 - loss: 0.0777 - val_Precision: 1.0000 - val_Recall: 0.9514 - val_accuracy: 0.9514 - val_f1_score: 1.0000 - val_loss: 0.1503
# Epoch 69/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.9583 - Recall: 0.9762 - accuracy: 0.9751 - f1_score: 0.6219 - loss: 0.0715 - val_Precision: 1.0000 - val_Recall: 0.9309 - val_accuracy: 0.9309 - val_f1_score: 1.0000 - val_loss: 0.1858
# Epoch 70/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9586 - Recall: 0.9745 - accuracy: 0.9746 - f1_score: 0.6220 - loss: 0.0718 - val_Precision: 1.0000 - val_Recall: 0.8951 - val_accuracy: 0.8951 - val_f1_score: 1.0000 - val_loss: 0.2378
# Epoch 71/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9534 - Recall: 0.9749 - accuracy: 0.9727 - f1_score: 0.6219 - loss: 0.0718 - val_Precision: 1.0000 - val_Recall: 0.8363 - val_accuracy: 0.8363 - val_f1_score: 1.0000 - val_loss: 0.3495
# Epoch 72/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9589 - Recall: 0.9720 - accuracy: 0.9738 - f1_score: 0.6239 - loss: 0.0687 - val_Precision: 1.0000 - val_Recall: 0.9130 - val_accuracy: 0.9130 - val_f1_score: 1.0000 - val_loss: 0.2341
# Epoch 73/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9611 - Recall: 0.9754 - accuracy: 0.9759 - f1_score: 0.6250 - loss: 0.0664 - val_Precision: 1.0000 - val_Recall: 0.9060 - val_accuracy: 0.9060 - val_f1_score: 1.0000 - val_loss: 0.2186
# Epoch 74/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9606 - Recall: 0.9741 - accuracy: 0.9752 - f1_score: 0.6242 - loss: 0.0689 - val_Precision: 1.0000 - val_Recall: 0.8331 - val_accuracy: 0.8331 - val_f1_score: 1.0000 - val_loss: 0.3514
# Epoch 75/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9555 - Recall: 0.9758 - accuracy: 0.9738 - f1_score: 0.6296 - loss: 0.0715 - val_Precision: 1.0000 - val_Recall: 0.8824 - val_accuracy: 0.8824 - val_f1_score: 1.0000 - val_loss: 0.2686
# Epoch 76/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9635 - Recall: 0.9771 - accuracy: 0.9775 - f1_score: 0.6281 - loss: 0.0657 - val_Precision: 1.0000 - val_Recall: 0.9450 - val_accuracy: 0.9450 - val_f1_score: 1.0000 - val_loss: 0.1414
# Epoch 77/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9594 - Recall: 0.9745 - accuracy: 0.9749 - f1_score: 0.6329 - loss: 0.0685 - val_Precision: 1.0000 - val_Recall: 0.9246 - val_accuracy: 0.9246 - val_f1_score: 1.0000 - val_loss: 0.1664
# Epoch 78/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9582 - Recall: 0.9737 - accuracy: 0.9741 - f1_score: 0.6305 - loss: 0.0678 - val_Precision: 1.0000 - val_Recall: 0.8670 - val_accuracy: 0.8670 - val_f1_score: 1.0000 - val_loss: 0.2976
# Epoch 79/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9644 - Recall: 0.9779 - accuracy: 0.9781 - f1_score: 0.6333 - loss: 0.0624 - val_Precision: 1.0000 - val_Recall: 0.9386 - val_accuracy: 0.9386 - val_f1_score: 1.0000 - val_loss: 0.1514
# Epoch 80/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9631 - Recall: 0.9762 - accuracy: 0.9770 - f1_score: 0.6350 - loss: 0.0628 - val_Precision: 1.0000 - val_Recall: 0.9476 - val_accuracy: 0.9476 - val_f1_score: 1.0000 - val_loss: 0.1357
# Epoch 81/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9606 - Recall: 0.9741 - accuracy: 0.9752 - f1_score: 0.6366 - loss: 0.0651 - val_Precision: 1.0000 - val_Recall: 0.9578 - val_accuracy: 0.9578 - val_f1_score: 1.0000 - val_loss: 0.1137
# Epoch 82/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9612 - Recall: 0.9796 - accuracy: 0.9775 - f1_score: 0.6386 - loss: 0.0645 - val_Precision: 1.0000 - val_Recall: 0.9540 - val_accuracy: 0.9540 - val_f1_score: 1.0000 - val_loss: 0.1133
# Epoch 83/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9701 - Recall: 0.9805 - accuracy: 0.9813 - f1_score: 0.6359 - loss: 0.0592 - val_Precision: 1.0000 - val_Recall: 0.9373 - val_accuracy: 0.9373 - val_f1_score: 1.0000 - val_loss: 0.1601
# Epoch 84/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9645 - Recall: 0.9813 - accuracy: 0.9794 - f1_score: 0.6393 - loss: 0.0592 - val_Precision: 1.0000 - val_Recall: 0.9425 - val_accuracy: 0.9425 - val_f1_score: 1.0000 - val_loss: 0.1442
# Epoch 85/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9660 - Recall: 0.9792 - accuracy: 0.9792 - f1_score: 0.6353 - loss: 0.0610 - val_Precision: 1.0000 - val_Recall: 0.8568 - val_accuracy: 0.8568 - val_f1_score: 1.0000 - val_loss: 0.3105
# Epoch 86/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9660 - Recall: 0.9783 - accuracy: 0.9789 - f1_score: 0.6406 - loss: 0.0606 - val_Precision: 1.0000 - val_Recall: 0.9469 - val_accuracy: 0.9469 - val_f1_score: 1.0000 - val_loss: 0.1258
# Epoch 87/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9648 - Recall: 0.9788 - accuracy: 0.9786 - f1_score: 0.6409 - loss: 0.0589 - val_Precision: 1.0000 - val_Recall: 0.8855 - val_accuracy: 0.8855 - val_f1_score: 1.0000 - val_loss: 0.2809
# Epoch 88/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.9656 - Recall: 0.9788 - accuracy: 0.9789 - f1_score: 0.6451 - loss: 0.0574 - val_Precision: 1.0000 - val_Recall: 0.9348 - val_accuracy: 0.9348 - val_f1_score: 1.0000 - val_loss: 0.1448
# Epoch 89/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - Precision: 0.9656 - Recall: 0.9792 - accuracy: 0.9791 - f1_score: 0.6457 - loss: 0.0573 - val_Precision: 1.0000 - val_Recall: 0.9629 - val_accuracy: 0.9629 - val_f1_score: 1.0000 - val_loss: 0.1098
# Epoch 90/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9613 - Recall: 0.9809 - accuracy: 0.9779 - f1_score: 0.6458 - loss: 0.0590 - val_Precision: 1.0000 - val_Recall: 0.9469 - val_accuracy: 0.9469 - val_f1_score: 1.0000 - val_loss: 0.1322
# Epoch 91/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9689 - Recall: 0.9792 - accuracy: 0.9803 - f1_score: 0.6476 - loss: 0.0547 - val_Precision: 1.0000 - val_Recall: 0.9648 - val_accuracy: 0.9648 - val_f1_score: 1.0000 - val_loss: 0.0908
# Epoch 92/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9669 - Recall: 0.9796 - accuracy: 0.9797 - f1_score: 0.6493 - loss: 0.0577 - val_Precision: 1.0000 - val_Recall: 0.9597 - val_accuracy: 0.9597 - val_f1_score: 1.0000 - val_loss: 0.1177
# Epoch 93/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9640 - Recall: 0.9779 - accuracy: 0.9779 - f1_score: 0.6500 - loss: 0.0565 - val_Precision: 1.0000 - val_Recall: 0.8568 - val_accuracy: 0.8568 - val_f1_score: 1.0000 - val_loss: 0.3200
# Epoch 94/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9689 - Recall: 0.9800 - accuracy: 0.9806 - f1_score: 0.6464 - loss: 0.0577 - val_Precision: 1.0000 - val_Recall: 0.9482 - val_accuracy: 0.9482 - val_f1_score: 1.0000 - val_loss: 0.1353
# Epoch 95/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9722 - Recall: 0.9822 - accuracy: 0.9827 - f1_score: 0.6531 - loss: 0.0517 - val_Precision: 1.0000 - val_Recall: 0.9425 - val_accuracy: 0.9425 - val_f1_score: 1.0000 - val_loss: 0.1388
# Epoch 96/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9698 - Recall: 0.9834 - accuracy: 0.9822 - f1_score: 0.6564 - loss: 0.0541 - val_Precision: 1.0000 - val_Recall: 0.9482 - val_accuracy: 0.9482 - val_f1_score: 1.0000 - val_loss: 0.1390
# Epoch 97/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9665 - Recall: 0.9813 - accuracy: 0.9802 - f1_score: 0.6542 - loss: 0.0575 - val_Precision: 1.0000 - val_Recall: 0.9329 - val_accuracy: 0.9329 - val_f1_score: 1.0000 - val_loss: 0.1561
# Epoch 98/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9727 - Recall: 0.9834 - accuracy: 0.9834 - f1_score: 0.6551 - loss: 0.0544 - val_Precision: 1.0000 - val_Recall: 0.8766 - val_accuracy: 0.8766 - val_f1_score: 1.0000 - val_loss: 0.2758
# Epoch 99/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9690 - Recall: 0.9826 - accuracy: 0.9816 - f1_score: 0.6567 - loss: 0.0527 - val_Precision: 1.0000 - val_Recall: 0.9226 - val_accuracy: 0.9226 - val_f1_score: 1.0000 - val_loss: 0.1913
# Epoch 100/100
# 196/196 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - Precision: 0.9703 - Recall: 0.9864 - accuracy: 0.9835 - f1_score: 0.6553 - loss: 0.0495 - val_Precision: 1.0000 - val_Recall: 0.8996 - val_accuracy: 0.8996 - val_f1_score: 1.0000 - val_loss: 0.2244

# %% [markdown]
# # Evaluation of Result

# %%
loss, accuracy, precision, recall,f1_score= model.evaluate(X_res,y_res)
print(f"Loss: {loss*100}")
print(f"Accuracy: {accuracy*100}")
print(f"Precision: {precision*100}")
print(f"Recall: {recall}")
print(f"f1_score: {f1_score}")
# Out:
# 245/245 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - Precision: 0.9864 - Recall: 0.9456 - accuracy: 0.9662 - f1_score: 0.7554 - loss: 0.0852
# Loss: 8.524208515882492
# Accuracy: 96.62274718284607
# Precision: 98.64181280136108
# Recall: 0.94562166929245
# f1_score: 0.7553755044937134

# %% [markdown]
# # Save the Model

# %%
model.save('stroke_prediction.keras')

# %% [markdown]
# # Graph Representation Of Training Loss & Validation Loss

# %%
plt.figure(figsize=(12,6))
plt.plot(history.history['loss'],label='Training Loss')
plt.plot(history.history['val_loss'],label='Validation Loss')
plt.title('Model Loss',color='red',fontsize=15)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train','Validation'],loc='upper right')
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(history.history['accuracy'],label='Training Accuracy')
plt.plot(history.history['val_accuracy'],label='Validation Accuracy')
plt.title('Model Accuracy',color='red',fontsize=15)
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train','Validation'],loc='lower right')
plt.show()

# %% [markdown]
# # **Test the Prediction**

# %%
df.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart disease', 'Married',
#        'Work Type', 'Residence_type', 'Avg_Glucose_Level', 'bmi',
#        'Smoking Status', 'stroke'],
#       dtype='object')

# %%
new_data = pd.DataFrame({
    'gender': ['Female'],
    'age': [61],
    'hypertension': [0],
    'heart disease': [0],
    'Married': ['Yes'],
    'Work Type': ['Self-employed'],
    'Residence_type': ['Rural'],
    'Avg_Glucose_Level': [202.21],
    'bmi': [28.89],
    'Smoking Status': ['never smoked']
})



new_data_transformed = column_trans.transform(new_data)

# %%
prediction = model.predict(new_data_transformed)
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# [[0.72723866]]

# %%
prediction_class = (prediction > 0.5).astype(int)
print(prediction_class)
# Out:
# [[1]]

# %%
df.head()
# Out:
#    gender  age  hypertension  heart disease Married      Work Type  \
# 0    Male   67             0              1     Yes        Private
# 1  Female   61             0              0     Yes  Self-employed
# 2    Male   80             0              1     Yes        Private
# 3  Female   49             0              0     Yes        Private
# 4  Female   79             1              0     Yes  Self-employed
#
#   Residence_type  Avg_Glucose_Level   bmi   Smoking Status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             202.21  28.1     never smoked       1
# 2          Rural             105.92  32.5     never smoked       1
# 3          Urban             171.23  34.4           smokes       1
# 4          Rural             174.12  24.0     never smoked       1
